# %%
import matplotlib.pyplot as plt
import matplotlib.image as im
import sys
import numpy as np

# %%
image = im.imread("Images/2_of_clubs.png")
image.shape
# Out:
# (726, 500, 4)

# %%
plt.imshow(image)
sys.executable
# Out:
# 'C:\\Users\\mparry\\Anaconda3\\python.exe'

# %%
sys.path
# Out:
# ['C:\\Users\\mparry\\OneDrive - GMIT\\Programming_for_Data_Analysis\\Code\\Project\\PDA-Numpy',
#  'C:\\Users\\mparry\\Anaconda3\\python38.zip',
#  'C:\\Users\\mparry\\Anaconda3\\DLLs',
#  'C:\\Users\\mparry\\Anaconda3\\lib',
#  'C:\\Users\\mparry\\Anaconda3',
#  '',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\mparry\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\mparry\\.ipython']

# %%
from PIL import Image

# %% [markdown]
# https://berkeley-stat159-f17.github.io/stat159-f17/lectures/10-matplotlib_beyond_basics/image_tutorial..html

# %%
img = Image.open("Images/2_of_clubs.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x726 at 0x223E0C329A0>

# %%
rsize = img.resize((np.array(img.size)/5).astype(int)) # Use PIL to resize
rsize
# Out:
# <PIL.Image.Image image mode=RGBA size=100x145 at 0x223DC26C7F0>
